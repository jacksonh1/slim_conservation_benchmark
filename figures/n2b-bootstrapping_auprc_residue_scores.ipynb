# %% [markdown]
# # plan
#
# - import wide form score table and the score index key
# - use the mask array to convert the score lists to single value scores
# - generate bootstrapping replicates - 1000x
#   - resample the table with replacement 1000x and store results in a list of dataframes
#   - resampled replicates will have the same number or TPs and FPs for each SLiM as the original data
#   - convert each replicate into a long form table
#   - calculate auPRC scores for each replicate - both combined and for each SLiM
# - calculate confidence intervals to use for error bars
# - calculate significance of differences between auPRC scores that I refer to use in the manuscript

# %%
import slim_conservation_scoring.seqtools.general_utils as tools
import pandas as pd
import numpy as np
import slim_conservation_scoring.pipeline.group_conservation_objects as group_tools
import json
import os
import re
import sys
from pathlib import Path
from Bio import AlignIO, Seq, SeqIO, Align
import matplotlib.pyplot as plt
plt.style.use('custom_standard')
# plt.style.use('custom_small')
import seaborn as sns
# pd.options.plotting.backend = "plotly"
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
zscores = pd.read_csv('./z_scores_wideform.csv')
score_key = pd.read_csv('./z_scores_score_key.csv')
score_indexes=[i for i in zscores.columns if i in score_key['score_index'].unique()]

from ast import literal_eval
for col in score_indexes:
    zscores[col] = zscores[col].apply(literal_eval)

zscores['mask_array'] = zscores['mask_array'].str.replace(' ', ',')
zscores['mask_array'] = zscores['mask_array'].apply(literal_eval)

def extract_important_scores(s, colname):
    scores = np.array(s[colname])
    maskarr = np.array(s["mask_array"])
    mask = maskarr.nonzero()
    return scores[mask]

zscores2=zscores.copy()
for i in score_indexes:
    zscores2[i] = zscores2.apply(lambda x: extract_important_scores(x, i), axis=1)


zscores2['hit_sequence_residues'] = zscores2['hit_sequence'].apply(list)
zscores2['hit_sequence_residues_masked'] = zscores2.apply(
    lambda x: extract_important_scores(x, 'hit_sequence_residues'), axis=1
)
zscores2 = zscores2[zscores2['ELM_motif_class'] != 'TRAF6']
zscores3 = zscores2.explode(score_indexes+['hit_sequence_residues_masked'])

# %%
auprc_dict = {}
for i in score_indexes:
    prc_results = tools.df_2_precision_recall_curve(zscores3, 'verified interaction', score_col=i)
    auprc_dict[i] = prc_results[3]
general_auprc_df = score_key[score_key['score_index'].isin(score_indexes)].copy()
general_auprc_df['auPRC'] = general_auprc_df['score_index'].map(auprc_dict)

# %%
temp = general_auprc_df[
    (general_auprc_df['rflank']!='5.0')
].copy()
temp=temp[temp['score_key']!='pairk_aln_dr_bert_embedding_lf0_rf0']
fig, ax = plt.subplots(figsize=(6.5, 6))
sns.barplot(
    data=temp, 
    x='level', 
    y='auPRC', 
    hue='score_key', 
    hue_order=[
        'aln_property_entropy',
        'pairk_aln_lf0_rf0_edssmat50',
        'pairk_aln_embedding_lf0_rf0',
        'kibby',
    ],
    palette={'aln_property_entropy': '#7f8585', 'kibby': '#b2abd2', 'pairk_aln_lf0_rf0_edssmat50': '#cc2529', 'pairk_aln_embedding_lf0_rf0':'#fdb863'},
    ax=ax,
    legend=False,
)
# Out:
# <Axes: xlabel='level', ylabel='auPRC'>

# %%
def get_stratified_sample(dfin, class_col):
    df = dfin.copy()
    tp = df[df[class_col]==True].copy().sample(frac=1, replace=True)
    fp = df[df[class_col]==False].copy().sample(frac=1, replace=True)
    return pd.concat([tp, fp], ignore_index=True)


def make_bootstrap_sample(dfin):
    df = dfin.copy()
    motifs = df['ELM_motif_class'].unique()
    t = [get_stratified_sample(df[df['ELM_motif_class']==i].copy(), 'verified interaction') for i in motifs]
    return pd.concat(t, ignore_index=True)

# %%
n_bootstraps = 1000
counter = 0
bootstrap_samples = []
for i in range(n_bootstraps):
    bootstrap_samples.append(make_bootstrap_sample(zscores3))
    counter += 1
    if counter % 100 == 0:
        print(f"Completed {counter} bootstraps")
# Out:
# Completed 100 bootstraps
# Completed 200 bootstraps
# Completed 300 bootstraps
# Completed 400 bootstraps
# Completed 500 bootstraps
# Completed 600 bootstraps
# Completed 700 bootstraps
# Completed 800 bootstraps
# Completed 900 bootstraps
# Completed 1000 bootstraps

# %% [markdown]
# # general auPRC - combining all of the SLiMs and treating as a single dataset

# %%
from collections import defaultdict
bootstrap_auprc_dict = defaultdict(list)
for i in score_indexes:
    for sample in bootstrap_samples:
        prc_results = tools.df_2_precision_recall_curve(sample, 'verified interaction', score_col=i)
        bootstrap_auprc_dict[i].append(prc_results[3])

# %%
confidence_intervals = defaultdict(list)
for k, v in bootstrap_auprc_dict.items():
    confidence_intervals[k] = np.percentile(v, [2.5, 97.5])

# %%
sns.histplot(bootstrap_auprc_dict['0.0'])
plt.axvline(confidence_intervals['0.0'][0], color='red')
plt.axvline(confidence_intervals['0.0'][1], color='red')
sns.histplot(bootstrap_auprc_dict['kibby_hit_zscores'])
plt.axvline(confidence_intervals['kibby_hit_zscores'][0], color='red')
plt.axvline(confidence_intervals['kibby_hit_zscores'][1], color='red')
plt.xlim(0, 1)
# Out:
# (0.0, 1.0)

# %% [markdown]
# put bootstrapping results into a dataframe

# %%
general_auprc_df = score_key[score_key['score_index'].isin(score_indexes)].copy()
general_auprc_df['CI'] = general_auprc_df['score_index'].map(confidence_intervals)
# split CI into two columns
general_auprc_df[['CI_lower', 'CI_upper']] = pd.DataFrame(general_auprc_df['CI'].tolist(), index=general_auprc_df.index)
general_auprc_df=general_auprc_df.drop(columns=['CI'])

# %% [markdown]
# add real auPRC score to the dataframe

# %%
auprc_dict = {}
for i in score_indexes:
    prc_results = tools.df_2_precision_recall_curve(zscores3, 'verified interaction', score_col=i)
    auprc_dict[i] = prc_results[3]
general_auprc_df['auPRC'] = general_auprc_df['score_index'].map(auprc_dict)

# %%
temp = general_auprc_df.copy()
temp = temp[temp["rflank"] != "5.0"]
temp = temp[temp["score_key"] != "pairk_aln_dr_bert_embedding_lf0_rf0"]
fig, ax = plt.subplots(figsize=(6.5, 6))
colormap = {
    "aln_property_entropy": "#7f8585",
    "kibby": "#b2abd2",
    "pairk_aln_lf0_rf0_edssmat50": "#cc2529",
    "pairk_aln_embedding_lf0_rf0": "#fdb863",
}
# change the saturation of the hex colors
colormap = {k: sns.desaturate(v, 0.75) for k, v in colormap.items()}
labels = general_auprc_df["level"].unique()
x = np.arange(len(labels))  # the label locations
width = 0.2  # the width of the bars
multiplier = 0
for i in temp["score_key"].unique():
    temp2 = temp[temp["score_key"] == i].copy()
    offset = width * multiplier
    rects = ax.bar(
        x + offset,
        temp2["auPRC"],
        width,
        label=i,
        color=colormap[i],
        yerr=[
            temp2["auPRC"] - temp2["CI_lower"],
            temp2["CI_upper"] - temp2["auPRC"],
        ],
        error_kw={"elinewidth": 1.5, "capthick": 1.5, "capsize": 4},
    )
    multiplier += 1

ax.set_xticks(x + width * 1.5, labels)
ax.set_xlim(-0.25, len(labels) - 0.15)
# ax.set_ylim(0, 0.5)
ax.set_xlabel('')
# remove the xticks
ax.set_xticks([])
# plt.xticks(rotation=60, horizontalalignment="right")
ax.set_ylabel("auPRC")
# plt.savefig('./figure4/auPRC_barplot_general-rbm_f.png', bbox_inches='tight', dpi=400)
# Out:
# Text(0, 0.5, 'auPRC')

# %%
temp = general_auprc_df.copy()
temp = temp[temp["rflank"] != "5.0"]
temp = temp[temp["score_key"].isin(["pairk_aln_dr_bert_embedding_lf0_rf0", "pairk_aln_embedding_lf0_rf0"])]
fig, ax = plt.subplots(figsize=(6.5, 6))
colormap = {
    "aln_property_entropy": "#7f8585",
    "kibby": "#b2abd2",
    "pairk_aln_lf0_rf0_edssmat50": "#cc2529",
    "pairk_aln_embedding_lf0_rf0": "#fdb863",
    'pairk_aln_dr_bert_embedding_lf0_rf0': '#7293cb',
}
# change the saturation of the hex colors
colormap = {k: sns.desaturate(v, 0.75) for k, v in colormap.items()}
labels = general_auprc_df["level"].unique()
x = np.arange(len(labels))  # the label locations
width = 0.4  # the width of the bars
multiplier = 1
for i in temp["score_key"].unique():
    temp2 = temp[temp["score_key"] == i].copy()
    offset = width * multiplier
    rects = ax.bar(
        x + offset,
        temp2["auPRC"],
        width,
        label=i,
        color=colormap[i],
        yerr=[
            temp2["auPRC"] - temp2["CI_lower"],
            temp2["CI_upper"] - temp2["auPRC"],
        ],
        error_kw={"elinewidth": 1.5, "capthick": 1.5, "capsize": 4},
    )
    multiplier += 1

ax.set_xticks(x + width * 1.5, labels)
ax.set_xlim(-0, len(labels) + 0.2)
# ax.set_ylim(0, 0.5)
ax.set_xlabel('')
# remove the xticks
ax.set_xticks([])
# plt.xticks(rotation=60, horizontalalignment="right")
ax.set_ylabel("auPRC")
# plt.savefig('./supplement/dr_bert/auPRC_barplot_general.png', bbox_inches='tight', dpi=400)
# Out:
# Text(0, 0.5, 'auPRC')

# %% [markdown]
# # per SLiM auPRC scores and bootstraps

# %% [markdown]
# real auPRC scores

# %%
from collections import defaultdict
auprc_slim_dict = defaultdict(list)
for s in zscores3['ELM_motif_class'].unique():
    temp = zscores3[zscores3['ELM_motif_class']==s].copy()
    for i in score_indexes:
        prc_results = tools.df_2_precision_recall_curve(temp, 'verified interaction', score_col=i)
        auprc_slim_dict['score_index'].append(i)
        auprc_slim_dict['ELM_motif_class'].append(s)
        auprc_slim_dict['auPRC'].append(prc_results[3])
auprc_slim_df = pd.DataFrame(auprc_slim_dict)
auprc_slim_df = pd.merge(auprc_slim_df, score_key, on='score_index', how='left')

# %%
auprc_slim_df[auprc_slim_df.duplicated(subset=['score_index', 'ELM_motif_class'])]
# Out:
#            score_index         ELM_motif_class     auPRC aln_type       level  \
# 16   kibby_hit_zscores          LIG_AP2alpha_2  0.270348    kibby   Tetrapoda
# 17   kibby_hit_zscores          LIG_AP2alpha_2  0.270348    kibby  Vertebrata
# 34   kibby_hit_zscores                LIG_EH_1  0.301504    kibby   Tetrapoda
# 35   kibby_hit_zscores                LIG_EH_1  0.301504    kibby  Vertebrata
# 52   kibby_hit_zscores        LIG_SH2_GRB2like  0.218351    kibby   Tetrapoda
# 53   kibby_hit_zscores        LIG_SH2_GRB2like  0.218351    kibby  Vertebrata
# 70   kibby_hit_zscores  LIG_SH3_CIN85_PxpxPR_1  0.275869    kibby   Tetrapoda
# 71   kibby_hit_zscores  LIG_SH3_CIN85_PxpxPR_1  0.275869    kibby  Vertebrata
# 88   kibby_hit_zscores           DOC_WW_Pin1_4  0.151415    kibby   Tetrapoda
# 89   kibby_hit_zscores           DOC_WW_Pin1_4  0.151415    kibby  Vertebrata
# 106  kibby_hit_zscores      LIG_14-3-3_CanoR_1  0.267353    kibby   Tetrapoda
# 107  kibby_hit_zscores      LIG_14-3-3_CanoR_1  0.267353    kibby  Vertebrata
# 124  kibby_hit_zscores     Ena/VASP ([FL]PPPP)  0.285620    kibby   Tetrapoda
# 125  kibby_hit_zscores     Ena/VASP ([FL]PPPP)  0.285620    kibby  Vertebrata
#
#     score_key table_file lflank rflank columnwise_score_function_name  \
# 16      kibby      kibby  kibby  kibby                          kibby
# 17      kibby      kibby  kibby  kibby                          kibby
# 34      kibby      kibby  kibby  kibby                          kibby
# 35      kibby      kibby  kibby  kibby                          kibby
# 52      kibby      kibby  kibby  kibby                          kibby
# 53      kibby      kibby  kibby  kibby                          kibby
# 70      kibby      kibby  kibby  kibby                          kibby
# 71      kibby      kibby  kibby  kibby                          kibby
# 88      kibby      kibby  kibby  kibby                          kibby
# 89      kibby      kibby  kibby  kibby                          kibby
# 106     kibby      kibby  kibby  kibby                          kibby
# 107     kibby      kibby  kibby  kibby                          kibby
# 124     kibby      kibby  kibby  kibby                          kibby
# 125     kibby      kibby  kibby  kibby                          kibby
#
#     num_passing
# 16        kibby
# 17        kibby
# 34        kibby
# 35        kibby
# 52        kibby
# 53        kibby
# 70        kibby
# 71        kibby
# 88        kibby
# 89        kibby
# 106       kibby
# 107       kibby
# 124       kibby
# 125       kibby

# %% [markdown]
# Bootstrap auprc and confidence intervals

# %%
bootstrap_slim_dict = defaultdict(list)
for slim in zscores3['ELM_motif_class'].unique():
    auprc_dict_s = defaultdict(list)
    for sample in bootstrap_samples:
        sample_s = sample[sample['ELM_motif_class']==slim].copy()
        for i in score_indexes:
            prc_results = tools.df_2_precision_recall_curve(sample_s, 'verified interaction', score_col=i)
            auprc_dict_s[i].append(prc_results[3])
    for score_index, auprc_list in auprc_dict_s.items():
        bootstrap_slim_dict['score_index'].append(score_index)
        bootstrap_slim_dict['ELM_motif_class'].append(slim)
        bootstrap_slim_dict['CI'].append(np.percentile(auprc_list, [2.5, 97.5]))

# %%
bootstrap_slim_df=pd.DataFrame(bootstrap_slim_dict)
auprc_slim_df=pd.merge(auprc_slim_df, bootstrap_slim_df, on=['score_index', 'ELM_motif_class'], how='left')
auprc_slim_df[['CI_lower', 'CI_upper']] = pd.DataFrame(auprc_slim_df['CI'].tolist(), index=auprc_slim_df.index)
auprc_slim_df=auprc_slim_df.drop(columns=['CI'])

# %%
auprc_slim_df
# Out:
#            score_index      ELM_motif_class     auPRC            aln_type  \
# 0                  0.0       LIG_AP2alpha_2  0.222444         MSA - MAFFT
# 1                  2.0       LIG_AP2alpha_2  0.210928         MSA - MAFFT
# 2                  4.0       LIG_AP2alpha_2  0.210710         MSA - MAFFT
# 3                  8.0       LIG_AP2alpha_2  0.212866            Pairwise
# 4                  9.0       LIG_AP2alpha_2  0.238822            Pairwise
# ..                 ...                  ...       ...                 ...
# 121               38.0  Ena/VASP ([FL]PPPP)  0.278147  Pairwise embedding
# 122               39.0  Ena/VASP ([FL]PPPP)  0.266515  Pairwise embedding
# 123  kibby_hit_zscores  Ena/VASP ([FL]PPPP)  0.285620               kibby
# 124  kibby_hit_zscores  Ena/VASP ([FL]PPPP)  0.285620               kibby
# 125  kibby_hit_zscores  Ena/VASP ([FL]PPPP)  0.285620               kibby
#
#           level                            score_key  \
# 0     Tetrapoda                 aln_property_entropy
# 1    Vertebrata                 aln_property_entropy
# 2       Metazoa                 aln_property_entropy
# 3     Tetrapoda          pairk_aln_lf0_rf0_edssmat50
# 4     Tetrapoda          pairk_aln_lf5_rf5_edssmat50
# ..          ...                                  ...
# 121     Metazoa          pairk_aln_embedding_lf0_rf0
# 122     Metazoa  pairk_aln_dr_bert_embedding_lf0_rf0
# 123     Metazoa                                kibby
# 124   Tetrapoda                                kibby
# 125  Vertebrata                                kibby
#
#                                             table_file lflank rflank  \
# 0    /home/jch/Documents/08-benchmark/benchmark/ben...    MSA    MSA
# 1    /home/jch/Documents/08-benchmark/benchmark/ben...    MSA    MSA
# 2    /home/jch/Documents/08-benchmark/benchmark/ben...    MSA    MSA
# 3    /home/jch/Documents/08-benchmark/benchmark/ben...    0.0    0.0
# 4    /home/jch/Documents/08-benchmark/benchmark/ben...    5.0    5.0
# ..                                                 ...    ...    ...
# 121  /home/jch/Documents/08-benchmark/benchmark/ben...    0.0    0.0
# 122  /home/jch/Documents/08-benchmark/benchmark/ben...    0.0    0.0
# 123                                              kibby  kibby  kibby
# 124                                              kibby  kibby  kibby
# 125                                              kibby  kibby  kibby
#
#     columnwise_score_function_name num_passing  CI_lower  CI_upper
# 0                 property_entropy        2464  0.194640  0.260428
# 1                 property_entropy        2606  0.186558  0.239757
# 2                 property_entropy        2404  0.184757  0.245364
# 3                 property_entropy        2663  0.195993  0.233260
# 4                 property_entropy        2565  0.216063  0.267135
# ..                             ...         ...       ...       ...
# 121               property_entropy        2844  0.226727  0.348312
# 122               property_entropy        2844  0.225373  0.334943
# 123                          kibby       kibby  0.229062  0.353269
# 124                          kibby       kibby  0.229062  0.353269
# 125                          kibby       kibby  0.229062  0.353269
#
# [126 rows x 13 columns]

# %%
temp = auprc_slim_df.copy()
temp = temp[
    (temp["level"] == "Metazoa")
].copy()
temp = temp[temp["rflank"] != "5.0"]
temp = temp[temp["score_key"] != "pairk_aln_dr_bert_embedding_lf0_rf0"]
# fig, ax = plt.subplots(figsize=(12, 8.5))
fig, ax = plt.subplots(figsize=(13, 5.5))
colormap = {
    "aln_property_entropy": "#7f8585",
    "kibby": "#b2abd2",
    "pairk_aln_lf0_rf0_edssmat50": "#cc2529",
    "pairk_aln_embedding_lf0_rf0": "#fdb863",
}
# change the saturation of the hex colors
colormap = {k: sns.desaturate(v, 0.75) for k, v in colormap.items()}
labels = temp["ELM_motif_class"].unique()
x = np.arange(len(labels))  # the label locations
width = 0.2  # the width of the bars
multiplier = 0
for i in temp["score_key"].unique():
    temp2 = temp[temp["score_key"] == i].copy()
    offset = width * multiplier
    rects = ax.bar(
        x + offset,
        temp2["auPRC"],
        width,
        label=i,
        color=colormap[i],
        yerr=[
            temp2["auPRC"] - temp2["CI_lower"],
            temp2["CI_upper"] - temp2["auPRC"],
        ],
        error_kw={"elinewidth": 0.75, "capthick": 0.75, "capsize": 2},
    )
    multiplier += 1

ax.set_xticks(x + width * 1.5, labels)
ax.set_xlim(-0.25, len(labels) - 0.15)
plt.xticks(rotation=60, horizontalalignment="right")
ax.set_ylabel("auPRC")
# plt.savefig('./figure3/auPRC_barplot_classes_metazoa-rbm_f.png', bbox_inches='tight', dpi=400)
# Out:
# Text(0, 0.5, 'auPRC')

# %%
temp = auprc_slim_df.copy()
temp = temp[
    (temp["level"] == "Metazoa")
].copy()
temp = temp[temp["rflank"] != "5.0"]
temp = temp[temp["score_key"].isin(["pairk_aln_dr_bert_embedding_lf0_rf0", "pairk_aln_embedding_lf0_rf0"])]
fig, ax = plt.subplots(figsize=(6.5, 6))
# fig, ax = plt.subplots(figsize=(13, 5.5))
colormap = {
    "aln_property_entropy": "#7f8585",
    "kibby": "#b2abd2",
    "pairk_aln_lf0_rf0_edssmat50": "#cc2529",
    "pairk_aln_embedding_lf0_rf0": "#fdb863",
    'pairk_aln_dr_bert_embedding_lf0_rf0': '#7293cb',
}
# change the saturation of the hex colors
colormap = {k: sns.desaturate(v, 0.75) for k, v in colormap.items()}
labels = temp["ELM_motif_class"].unique()
x = np.arange(len(labels))  # the label locations
width = 0.4  # the width of the bars
multiplier = 1
for i in temp["score_key"].unique():
    temp2 = temp[temp["score_key"] == i].copy()
    offset = width * multiplier
    rects = ax.bar(
        x + offset,
        temp2["auPRC"],
        width,
        label=i,
        color=colormap[i],
        yerr=[
            temp2["auPRC"] - temp2["CI_lower"],
            temp2["CI_upper"] - temp2["auPRC"],
        ],
        error_kw={"elinewidth": 0.75, "capthick": 0.75, "capsize": 2},
    )
    multiplier += 1

ax.set_xticks(x + width * 1.5, labels)
ax.set_xlim(-0, len(labels) + 0.2)
plt.xticks(rotation=60, horizontalalignment="right")
ax.set_ylabel("auPRC")
# plt.savefig('./supplement/dr_bert/auPRC_barplot_classes_metazoa.png', bbox_inches='tight', dpi=400)
# Out:
# Text(0, 0.5, 'auPRC')

# %%
temp = auprc_slim_df.copy()
temp = temp[temp["rflank"] != "5.0"]
temp = temp[temp["score_key"] != "pairk_aln_dr_bert_embedding_lf0_rf0"]

# %%
aln_df=temp[temp['aln_type']=='MSA - MAFFT'][["ELM_motif_class", "auPRC", "level"]].copy()
auprc_df_norm=pd.merge(temp, aln_df, on=['ELM_motif_class', 'level'], how='left', suffixes=('', '_aln'), validate='m:1')

auprc_df_norm["auPRC_diff"] = auprc_df_norm["auPRC"] - auprc_df_norm["auPRC_aln"]
auprc_df_norm["auPRC_increase"] = auprc_df_norm["auPRC"] / auprc_df_norm["auPRC_aln"]
auprc_df_norm["auPRC_log_increase"] = np.log10(
    auprc_df_norm["auPRC"] / auprc_df_norm["auPRC_aln"]
)
auprc_df_norm.tail(10)
# Out:
#           score_index      ELM_motif_class     auPRC            aln_type  \
# 74                4.0  Ena/VASP ([FL]PPPP)  0.225220         MSA - MAFFT
# 75                8.0  Ena/VASP ([FL]PPPP)  0.222203            Pairwise
# 76               19.0  Ena/VASP ([FL]PPPP)  0.264708            Pairwise
# 77               26.0  Ena/VASP ([FL]PPPP)  0.238677            Pairwise
# 78               30.0  Ena/VASP ([FL]PPPP)  0.224805  Pairwise embedding
# 79               34.0  Ena/VASP ([FL]PPPP)  0.267330  Pairwise embedding
# 80               38.0  Ena/VASP ([FL]PPPP)  0.278147  Pairwise embedding
# 81  kibby_hit_zscores  Ena/VASP ([FL]PPPP)  0.285620               kibby
# 82  kibby_hit_zscores  Ena/VASP ([FL]PPPP)  0.285620               kibby
# 83  kibby_hit_zscores  Ena/VASP ([FL]PPPP)  0.285620               kibby
#
#          level                    score_key  \
# 74     Metazoa         aln_property_entropy
# 75   Tetrapoda  pairk_aln_lf0_rf0_edssmat50
# 76  Vertebrata  pairk_aln_lf0_rf0_edssmat50
# 77     Metazoa  pairk_aln_lf0_rf0_edssmat50
# 78   Tetrapoda  pairk_aln_embedding_lf0_rf0
# 79  Vertebrata  pairk_aln_embedding_lf0_rf0
# 80     Metazoa  pairk_aln_embedding_lf0_rf0
# 81     Metazoa                        kibby
# 82   Tetrapoda                        kibby
# 83  Vertebrata                        kibby
#
#                                            table_file lflank rflank  \
# 74  /home/jch/Documents/08-benchmark/benchmark/ben...    MSA    MSA
# 75  /home/jch/Documents/08-benchmark/benchmark/ben...    0.0    0.0
# 76  /home/jch/Documents/08-benchmark/benchmark/ben...    0.0    0.0
# 77  /home/jch/Documents/08-benchmark/benchmark/ben...    0.0    0.0
# 78  /home/jch/Documents/08-benchmark/benchmark/ben...    0.0    0.0
# 79  /home/jch/Documents/08-benchmark/benchmark/ben...    0.0    0.0
# 80  /home/jch/Documents/08-benchmark/benchmark/ben...    0.0    0.0
# 81                                              kibby  kibby  kibby
# 82                                              kibby  kibby  kibby
# 83                                              kibby  kibby  kibby
#
#    columnwise_score_function_name num_passing  CI_lower  CI_upper  auPRC_aln  \
# 74               property_entropy        2404  0.187720  0.277011   0.225220
# 75               property_entropy        2663  0.191031  0.267081   0.252732
# 76               property_entropy        2823  0.228486  0.316269   0.241763
# 77               property_entropy        2844  0.207315  0.284697   0.225220
# 78               property_entropy        2663  0.195950  0.264983   0.252732
# 79               property_entropy        2823  0.226498  0.325018   0.241763
# 80               property_entropy        2844  0.226727  0.348312   0.225220
# 81                          kibby       kibby  0.229062  0.353269   0.225220
# 82                          kibby       kibby  0.229062  0.353269   0.252732
# 83                          kibby       kibby  0.229062  0.353269   0.241763
#
#     auPRC_diff  auPRC_increase  auPRC_log_increase
# 74    0.000000        1.000000            0.000000
# 75   -0.030530        0.879201           -0.055912
# 76    0.022945        1.094909            0.039378
# 77    0.013457        1.059752            0.025204
# 78   -0.027927        0.889500           -0.050854
# 79    0.025567        1.105753            0.043658
# 80    0.052928        1.235005            0.091669
# 81    0.060401        1.268185            0.103183
# 82    0.032888        1.130129            0.053128
# 83    0.043857        1.181406            0.072399

# %%
plot = sns.catplot(
    data=auprc_df_norm[auprc_df_norm['score_key']=='pairk_aln_lf0_rf0_edssmat50'],
    y="auPRC_diff",
    x='ELM_motif_class',
    hue='level',
    kind='bar',
    aspect=1.2,
    height=6,
    palette="YlOrRd",
    legend_out=True,
)
plot.set_ylabels('increase in auPRC')
plot.set_xticklabels(rotation=60, horizontalalignment="right")
# plt.savefig('./figure4/increase_in_auPRC_per_class.png', bbox_inches='tight', dpi=400)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Data and preprocessing
temp = auprc_df_norm.copy()
temp = temp[temp["rflank"] != "5.0"]
temp = temp[temp["score_key"].isin(['pairk_aln_lf0_rf0_edssmat50', 'aln_property_entropy'])]

# Colormap and saturation adjustment
colormap = {
    "aln_property_entropy": "#7f8585",
    "pairk_aln_lf0_rf0_edssmat50": "#cc2529",
}
colormap = {k: sns.desaturate(v, 0.75) for k, v in colormap.items()}

# Set up labels and x positions
labels = auprc_df_norm["level"].unique()
x = np.arange(len(labels))  # the label locations

# Create the figure and subplots
motif_classes = temp["ELM_motif_class"].unique()
n_motifs = len(motif_classes)
n_cols = 3  # Adjust this depending on how you want to layout the subplots
n_rows = int(np.ceil(n_motifs / n_cols))

fig, axes = plt.subplots(n_rows, n_cols, figsize=(15, 15), constrained_layout=True)

# Flatten axes in case there's more than 1 row
axes = axes.flatten()

# Plot each ELM motif class in its respective subplot
for idx, slm in enumerate(motif_classes):
    ax = axes[idx]
    temp2 = temp[temp["ELM_motif_class"] == slm].copy()
    width = 0.3  # width of bars
    multiplier = 1

    for i in temp2["score_key"].unique():
        temp3 = temp2[temp2["score_key"] == i].copy()
        offset = width * multiplier
        ax.bar(
            x + offset,
            temp3["auPRC"],
            width,
            label=i,
            color=colormap[i],
            yerr=[
                temp3["auPRC"] - temp3["CI_lower"],
                temp3["CI_upper"] - temp3["auPRC"],
            ],
            error_kw={"elinewidth": 1.5, "capthick": 1.5, "capsize": 4},
        )
        multiplier += 1

    # Set labels and titles for each subplot
    ax.set_xticks(x + width * 1.5, labels)
    ax.set_xlim(-0.15, len(labels) - 0)
    ax.set_title(slm)
    ax.set_ylabel("auPRC")
    ax.set_xticklabels(labels, rotation=60, ha="right")
    # remove the top and right spines
    ax.spines["top"].set_visible(False)
    ax.spines["right"].set_visible(False)

# add a legend to the right of the last subplot
fig.legend(
    loc="center right",
    labels=['MSA','PairK'],
    # title="Score Key",
    bbox_to_anchor=(0.6, 0.2),
    # increase fontsize of legend
    fontsize=24,
    # remove the border of the legend
    frameon=False,
)
# Hide any extra subplots if they exist
for i in range(idx + 1, len(axes)):
    fig.delaxes(axes[i])

# Add legend and display the plot
# plt.legend(['MSA','PairK'], loc='upper right')

# %%
id_cols = [
    'reference_index',
    'ELM_motif_class',
    'verified interaction',
    'regex',
    'UniprotID',
    'name',
    'gene_id',
    'hit end position',
    'hit start position',
    'hit_sequence',
    'json_file',
    'hit_length',
    'mask_array',
]
    # 'hit_sequence_residues',
    # 'hit_sequence_residues_masked',
# ] + [i for i in zscores3.columns if 'bg_STD' in i]
z_long = zscores3.melt(id_vars=id_cols, value_vars=score_indexes, var_name='score_index', value_name='z_scores')
# Out:
#    reference_index ELM_motif_class  verified interaction   regex UniprotID  \
# 0                0  LIG_AP2alpha_2                  True  DP[FW]    O08838
# 1                0  LIG_AP2alpha_2                  True  DP[FW]    O08838
# 2                0  LIG_AP2alpha_2                  True  DP[FW]    O08838
# 3                1  LIG_AP2alpha_2                  True  DP[FW]    Q05140
# 4                1  LIG_AP2alpha_2                  True  DP[FW]    Q05140
#
#   name         gene_id  hit end position  hit start position hit_sequence  \
# 0  NaN  10116_0:004cdf               358                 356          DPF
# 1  NaN  10116_0:004cdf               358                 356          DPF
# 2  NaN  10116_0:004cdf               358                 356          DPF
# 3  NaN  10116_0:002e5e               401                 399          DPF
# 4  NaN  10116_0:002e5e               401                 399          DPF
#
#                                            json_file  hit_length mask_array  \
# 0  /home/jch/Documents/08-benchmark/benchmark/ben...           3  [1, 1, 1]
# 1  /home/jch/Documents/08-benchmark/benchmark/ben...           3  [1, 1, 1]
# 2  /home/jch/Documents/08-benchmark/benchmark/ben...           3  [1, 1, 1]
# 3  /home/jch/Documents/08-benchmark/benchmark/ben...           3  [1, 1, 1]
# 4  /home/jch/Documents/08-benchmark/benchmark/ben...           3  [1, 1, 1]
#
#   score_index  z_scores
# 0         0.0  1.312759
# 1         0.0  1.312759
# 2         0.0  1.312759
# 3         0.0  0.180739
# 4         0.0  0.180739

# %%
temp=pd.merge(z_long, score_key, on='score_index', how='left')
temp = temp[(temp['rflank']!=5)].copy()
temp = temp[temp['score_key'].isin(['aln_property_entropy', 'pairk_aln_lf0_rf0_edssmat50'])]

# %%
p = sns.displot(
    temp,
    x="z_scores",
    hue="verified interaction",
    col="aln_type",
    row="level",
    # bins=np.linspace(-4,4,40),
    bins=40,
    stat="density",
    common_norm=False,
    col_order=["MSA - MAFFT", "Pairwise"],#, "Pairwise embedding"],
    height=4,
    aspect=1.5,
    facet_kws=dict(margin_titles=True),
    common_bins=True,
)
# plt.xlim([-4, 4])
p._legend.remove()
p.set_titles(f"Level: {{row_name}}\nAln type: {{col_name}}")
# show grid lines
for ax in p.axes.flat:
    ax.grid(True)
    ax.set_axisbelow(True)
# output_folder = Path('./supplement/score_distributions')
# output_folder.mkdir(parents=True, exist_ok=True)
# plt.savefig(output_folder / 'benchmark_score_distros_msa_v_pair.png', bbox_inches='tight', dpi=400)
