# %% [markdown]
# This should be run only after `../../ELM_instances/build_instance_map.ipynb` and `../../all_human_odb_sequences_removed_duplicates/get_all_human_proteins_in_odb.ipynb` have been run

# %% [markdown]
# add path to the IUPRED2A library in the file `./iupred_tools.py` as the variable `IUPRED_PATH`

# %%
from pathlib import Path
from pyprojroot import here

import orthodb_tools.sql_queries as sql_queries
import orthodb_tools.tools.general_utils as tools
import iupred_tools as iuptools
import numpy as np
import pandas as pd
import yaml
from Bio import Align, AlignIO, Seq, SeqIO
import re
# from local_env_variables import project_filepaths as fp

# %%
BENCHMARK_DIR = here() / "benchmark" / "benchmark_v4" / "p1_table"
BENCHMARK_DIR.mkdir(parents=True, exist_ok=True)

# %% [markdown]
# # Verified interactions/regexes from the ELM database

# %% [markdown]
# ## functions

# %%
def get_regex_matches(regex_pattern: str, seq_str: str):
    """searches for all matches of a regex pattern in a sequence string
    returns a generator object that yields the match sequence, start index, and end index

    Parameters
    ----------
    regex_pattern : str
        regular expression pattern
    seq_str : str
        string to search for matches

    Yields
    ------
    tuple
        (match sequence, start index, end index)
    """
    p = re.compile(regex_pattern)
    for m in p.finditer(seq_str):
        if m.start() == m.end():
            # even if there are groups in the lookahead, the first group should be the full match b/c that group surrounds the entire regex
            # so this will work whether or not there are groups in the lookahead
            match_seq = m.groups()[0]
        else:
            match_seq = seq_str[m.start() : m.end()]
        yield match_seq, m.start(), m.start() + len(match_seq) - 1

# %%
def in_any_idrs(idr_list: list, start: int, end: int):
    for idr in idr_list:
        if idr[0] <= start and end <= idr[1]:
            return True
    return False


def regex_search(regex, seqrecord_list, idr_map: dict = None):
    odb_id_ex = []
    hit_start_pos_ex = []
    hit_end_pos_ex = []
    motif_match_ex = []

    for record in seqrecord_list:
        sequence = str(record.seq)
        if idr_map is not None:
            idrs = idr_map[record.id]
        for m in get_regex_matches(regex, sequence):
            start_pos = m[1]
            end_pos = m[2]
            if idr_map is not None:
                if len(idrs) == 0:
                    continue
                if not in_any_idrs(idrs, start_pos, end_pos):
                    continue
            odb_id_ex.append(record.id)
            hit_start_pos_ex.append(start_pos)
            hit_end_pos_ex.append(end_pos)
            motif_match_ex.append(m[0])

    df_fp = pd.DataFrame(
        {
            "odb_id": odb_id_ex,
            "odb_mot_st": hit_start_pos_ex,
            "odb_mot_end": hit_end_pos_ex,
            "motif_match": motif_match_ex,
        }
    )
    df_fp["regex"] = regex
    return df_fp


def load_verified_from_instances(
    motif_class_name,
    elm_instances_df,
    allowed_organisms=["Homo sapiens", "Mus musculus", "Rattus norvegicus"],
):
    """Load the verified instances for 1 slim class from the table of verified instances. Filters out instances not in `allowed_organisms`

    Parameters
    ----------
    motif_class_name : str
        name of the motif class (in the table)
    elm_instances_df : pd.Dataframe
        Instances from the ELM (should be preprocessed)
    allowed_organisms : list, optional
        list of organisms to allow, by default ["Homo sapiens", "Mus musculus", "Rattus norvegicus"]

    Returns
    -------
    tuple
        returns the pd.Dataframe of instances and the regular expression of the motif
    """
    print(f"Getting motif benchmark table for {motif_class_name}")

    # import known binders
    df = elm_instances_df.copy()
    df = df[df["ELMIdentifier"] == motif_class_name].copy()
    df["verified interaction"] = True
    df = df.rename(
        columns={
            "uniprot2map": "UniprotID",
            "Regex": "regex",
            "ProteinName": "name",
            "hit_sequence": "flanked_motif_match",
        }
    )
    df = df[df["InstanceLogic"] == "true positive"]
    df2 = df[
        [
            # "Accession_inst",
            # "Accession_class",
            "Organism",
            # "Probability",
            # "ELMIdentifier",
            # "name",
            "Primary_Acc",
            "Accessions",
            # "PDB",
            # "FunctionalSiteName",
            # "Description",
            # 'uniprot2map',
            "UniprotID",
            # "fasta_id",
            "regex",
            "motif_match",
            # "flanked_motif_match",
            # "mot_start_pos_in_hit",
            "odb_id",
            # "odb_hit_start",
            # "odb_hit_end",
            "odb_mot_st",
            "odb_mot_end",
            "verified interaction",
        ]
    ].copy()

    print("restrict known binders to a subset of organisms (only ones close to human)")

    print(f"allowed organisms for known binding interactions {allowed_organisms}")
    df2 = df2[df2["Organism"].isin(allowed_organisms)]
    reglist = df2["regex"].unique()
    assert len(reglist) == 1, "More than one regex in dataframe of known binders"
    regex = reglist[0]
    return df2, regex


def add_clashes_with_known_instances(df_bg_in, instances_df):
    df_bg = df_bg_in.copy()
    clash_map = {}
    for i, row in df_bg.iterrows():
        elm_clash_flag = False
        if row["odb_id"] in instances_df["odb_id"].values:
            potential_overlaps = instances_df[instances_df["odb_id"] == row["odb_id"]]
            for j, instance_row in potential_overlaps.iterrows():
                if (
                    row["odb_mot_st"] <= instance_row["odb_mot_end"]
                    and row["odb_mot_end"] >= instance_row["odb_mot_st"]
                ):
                    elm_clash_flag = True
            if elm_clash_flag:
                clash_map[i] = True
            else:
                clash_map[i] = False
        else:
            clash_map[i] = False
    df_bg["clash"] = df_bg.index.map(clash_map)
    return df_bg


def get_bg_seqs(
    bg_seq_fasta_file,
    regex,
    instance_df,
    idr_map: dict = None,
    bg_organism="Homo sapiens",
):
    faimporter = tools.FastaImporter(bg_seq_fasta_file)
    bg_search_seqs = faimporter.import_as_list()
    df_bg = regex_search(regex, bg_search_seqs, idr_map=idr_map)
    df_bg["UniprotID"] = df_bg["odb_id"].apply(sql_queries.odb_gene_id_2_uniprotid)
    df_bg["verified interaction"] = False
    df_bg["Organism"] = bg_organism
    df_bg = add_clashes_with_known_instances(df_bg, instance_df)
    df_bg = df_bg[~df_bg["clash"]]
    df_bg = df_bg.drop(columns="clash")
    return df_bg


def merge_verified_and_fp_motifs(df_verified, df_bg, cluster_dict=None):
    # remove overlap with verified binders
    verified_binder_odids = list(df_verified["odb_id"].unique())
    if cluster_dict is not None:
        # for each verified binder, add all cluster members so that they're removed from fp as well
        for cluster in cluster_dict:
            if any([i in verified_binder_odids for i in cluster_dict[cluster]['all_members']]):
                print('added cluster members')
                verified_binder_odids.extend(cluster_dict[cluster]['all_members'])
        verified_binder_odids = list(set(verified_binder_odids))
    df_bg = df_bg[~df_bg["odb_id"].isin(verified_binder_odids)].copy()
    assert (
        df_bg["UniprotID"].isin(df_verified["UniprotID"].unique()).sum() == 0
    ), "False positives overlap with verified binders by uniprot id"
    df_verified["regex"] = df_verified["regex"].astype(str)
    df_verified["verified interaction"] = df_verified["verified interaction"].astype(
        bool
    )

    # # merge
    dfm = pd.concat([df_verified, df_bg]).reset_index(drop=True)
    return dfm
    # dfm.to_csv(f"./{motif_class_name}_motifs.csv", index=False)
    # for col in dfm.columns: print(col)


def main(
    elm_class,
    elm_instances_file,
    bg_seq_fasta_file,
    idr_map,
    bg_organism,
    subsample: int|None=None,
    cluster_dict=None,
):
    elm_instances_df = pd.read_csv(elm_instances_file)
    dftp, regex = load_verified_from_instances(elm_class, elm_instances_df)
    bg_df = get_bg_seqs(
        bg_seq_fasta_file,
        regex,
        elm_instances_df,
        idr_map=idr_map,
        bg_organism=bg_organism,
    )
    if subsample is not None and len(bg_df) > subsample:
        bg_df = bg_df.sample(subsample, random_state=42)
    dfm = merge_verified_and_fp_motifs(dftp, bg_df, cluster_dict=cluster_dict)
    dfm["ELM_motif_class"] = elm_class
    return dfm

# %% [markdown]
# ## load idr map for all human proteins

# %%
human_sequences = "../../../../data/orthodb_clustered_species_proteins/9606_6/all_human_proteins_in_odb.fasta"

idr_map = {}
faimporter = tools.FastaImporter(human_sequences)
all_human_seq_dict = faimporter.import_as_dict()
for k, v in all_human_seq_dict.items():
    idr_map[k] = iuptools.main_find_idr_regions(
        str(v.seq),
        iupred_cutoff=0.4,
        gap_merge_threshold=10,
        idr_min_length=8,
    )

# %% [markdown]
# ## generating tables for a variety of ELM motifs (classes)

# %%
ELM_CLASSES_4_BENCHMARK = [
    "LIG_AP2alpha_2",
    "LIG_EH_1",
    "LIG_SH2_GRB2like",
    "LIG_SH3_CIN85_PxpxPR_1",
    # "LIG_PDZ_Class_1",
    "DOC_WW_Pin1_4", # this will have to be subsampled because the regex is way too general
    # "LIG_LIR_Gen_1",
    "LIG_14-3-3_CanoR_1"
]
# This is to set the number of background sequences to sample for each motif class in the cases where there are too many background matches. This happens when the motif regex being too general
CLASS_BG_SAMPLING = {
    "LIG_AP2alpha_2": 350,
    "LIG_EH_1": 350,
    "LIG_SH2_GRB2like": 350,
    "LIG_SH3_CIN85_PxpxPR_1": 350,
    # "LIG_PDZ_Class_1": 300,
    "DOC_WW_Pin1_4": 350, # this will have to be subsampled because the regex is way too general
    # "LIG_LIR_Gen_1": 300,
    "LIG_14-3-3_CanoR_1": 350
}

# %%
BG_SEQ_FASTA_FILE = "../../../../data/orthodb_clustered_species_proteins/9606_6/all_human_proteins_in_odb_clustered_c0_95.fasta"
BG_CLUSTER_JSON_FILE = "../../../../data/orthodb_clustered_species_proteins/9606_6/all_human_proteins_in_odb_clustered_c0_95.json"
BG_ORGANISM = "Homo sapiens"
ELM_INSTANCES_FILE = "../../../../data/ELM/2024-02-09-ELM_instances/elm_instances_with_hit_sequence.csv"
import json
with open(BG_CLUSTER_JSON_FILE) as f:
    BG_CLUSTER_DICT = json.load(f)

# %%
# elm_instances_df = pd.read_csv(ELM_INSTANCES_FILE)
# dftp, regex = load_verified_from_instances(ELM_CLASSES_4_BENCHMARK[0], elm_instances_df)

# %%
# df = get_bg_seqs(BG_SEQ_FASTA_FILE, regex, elm_instances_df, idr_map=idr_map, bg_organism=BG_ORGANISM)
# df[df['clash']]

# %%
df_list = []
for motif in ELM_CLASSES_4_BENCHMARK:
    if motif in CLASS_BG_SAMPLING:
        df = main(
            elm_class=motif,
            elm_instances_file=ELM_INSTANCES_FILE,
            bg_seq_fasta_file=BG_SEQ_FASTA_FILE,
            idr_map=idr_map,
            bg_organism=BG_ORGANISM,
            subsample=CLASS_BG_SAMPLING[motif],
            cluster_dict=BG_CLUSTER_DICT
        )
    else:
        df = main(
            elm_class=motif,
            elm_instances_file=ELM_INSTANCES_FILE,
            bg_seq_fasta_file=BG_SEQ_FASTA_FILE,
            idr_map=idr_map,
            bg_organism=BG_ORGANISM,
            cluster_dict=BG_CLUSTER_DICT
        )
    df_list.append(df)
# Out:
# Getting motif benchmark table for LIG_AP2alpha_2
# restrict known binders to a subset of organisms (only ones close to human)
# allowed organisms for known binding interactions ['Homo sapiens', 'Mus musculus', 'Rattus norvegicus']
# added cluster members
# added cluster members
# added cluster members
# added cluster members
# Getting motif benchmark table for LIG_EH_1
# restrict known binders to a subset of organisms (only ones close to human)
# allowed organisms for known binding interactions ['Homo sapiens', 'Mus musculus', 'Rattus norvegicus']
# added cluster members
# added cluster members
# added cluster members
# added cluster members
# added cluster members
# added cluster members
# added cluster members
# added cluster members
# added cluster members
# added cluster members
# added cluster members
# added cluster members
# Getting motif benchmark table for LIG_SH2_GRB2like
# restrict known binders to a subset of organisms (only ones close to human)
# allowed organisms for known binding interactions ['Homo sapiens', 'Mus musculus', 'Rattus norvegicus']
# added cluster members
# added cluster members
# added cluster members
# added cluster members
# added cluster members
# added cluster members
# added cluster members
# added cluster members
# added cluster members
# added cluster members
# added cluster members
# added cluster members
# added cluster members
# added cluster members
# added cluster members
# added cluster members
# added cluster members
# Getting motif benchmark table for LIG_SH3_CIN85_PxpxPR_1
# restrict known binders to a subset of organisms (only ones close to human)
# allowed organisms for known binding interactions ['Homo sapiens', 'Mus musculus', 'Rattus norvegicus']
# added cluster members
# added cluster members
# added cluster members
# added cluster members
# added cluster members
# added cluster members
# added cluster members
# added cluster members
# added cluster members
# added cluster members
# added cluster members
# added cluster members
# added cluster members
# added cluster members
# added cluster members
# added cluster members
# added cluster members
# added cluster members
# added cluster members
# Getting motif benchmark table for DOC_WW_Pin1_4
# restrict known binders to a subset of organisms (only ones close to human)
# allowed organisms for known binding interactions ['Homo sapiens', 'Mus musculus', 'Rattus norvegicus']
# added cluster members
# added cluster members
# added cluster members
# added cluster members
# added cluster members
# added cluster members
# added cluster members
# added cluster members
# added cluster members
# added cluster members
# added cluster members
# added cluster members
# added cluster members
# added cluster members
# added cluster members
# added cluster members
# added cluster members
# added cluster members
# added cluster members
# added cluster members
# added cluster members
# added cluster members
# added cluster members
# added cluster members
# added cluster members
# added cluster members
# added cluster members
# added cluster members
# added cluster members
# added cluster members
# added cluster members
# added cluster members
# Getting motif benchmark table for LIG_14-3-3_CanoR_1
# restrict known binders to a subset of organisms (only ones close to human)
# allowed organisms for known binding interactions ['Homo sapiens', 'Mus musculus', 'Rattus norvegicus']
# added cluster members
# added cluster members
# added cluster members
# added cluster members
# added cluster members
# added cluster members
# added cluster members
# added cluster members
# added cluster members
# added cluster members
# added cluster members
# added cluster members
# added cluster members
# added cluster members
# added cluster members
# added cluster members
# added cluster members
# added cluster members
# added cluster members
# added cluster members
# added cluster members
# added cluster members
# added cluster members
# added cluster members
# added cluster members
# added cluster members
# added cluster members
# added cluster members
# added cluster members
# added cluster members

# %%
elms_df = pd.concat(df_list).reset_index(drop=True)
elms_df
# Out:
#                Organism Primary_Acc                          Accessions  \
# 0     Rattus norvegicus      O08838                              O08838
# 1     Rattus norvegicus      Q05140                              Q05140
# 2     Rattus norvegicus      Q05140                              Q05140
# 3          Homo sapiens      P98082  P98082 A6NES5 Q13598 Q9BTY0 Q9UK04
# 4          Homo sapiens      P98082  P98082 A6NES5 Q13598 Q9BTY0 Q9UK04
# ...                 ...         ...                                 ...
# 2380       Homo sapiens         NaN                                 NaN
# 2381       Homo sapiens         NaN                                 NaN
# 2382       Homo sapiens         NaN                                 NaN
# 2383       Homo sapiens         NaN                                 NaN
# 2384       Homo sapiens         NaN                                 NaN
#
#        UniprotID                                              regex  \
# 0         O08838                                             DP[FW]
# 1         Q05140                                             DP[FW]
# 2         Q05140                                             DP[FW]
# 3         P98082                                             DP[FW]
# 4         P98082                                             DP[FW]
# ...          ...                                                ...
# 2380  A0A384NPH9  R[^DE]{0,2}[^DEPG]([ST])(([FWYLMV].)|([^PRIKGN...
# 2381      Q9BWT1  R[^DE]{0,2}[^DEPG]([ST])(([FWYLMV].)|([^PRIKGN...
# 2382      A0PJX4  R[^DE]{0,2}[^DEPG]([ST])(([FWYLMV].)|([^PRIKGN...
# 2383      B3KUE8  R[^DE]{0,2}[^DEPG]([ST])(([FWYLMV].)|([^PRIKGN...
# 2384      O60331  R[^DE]{0,2}[^DEPG]([ST])(([FWYLMV].)|([^PRIKGN...
#
#       motif_match          odb_id  odb_mot_st  odb_mot_end  \
# 0             DPF  10116_0:004cdf         356          358
# 1             DPF  10116_0:002e5e         399          401
# 2             DPF  10116_0:002e5e         473          475
# 3             DPF   9606_0:0016b2         292          294
# 4             DPF   9606_0:0016b2         297          299
# ...           ...             ...         ...          ...
# 2380   RKSSSSRTPL   9606_0:000abb         504          513
# 2381   RRSRSSVTLP   9606_0:000b49         305          314
# 2382        RFSLR   9606_0:001415         134          138
# 2383  RATRSQQHTPV   9606_0:003ba5         843          853
# 2384      RGARSYP   9606_0:0045b2         491          497
#
#       verified interaction     ELM_motif_class
# 0                     True      LIG_AP2alpha_2
# 1                     True      LIG_AP2alpha_2
# 2                     True      LIG_AP2alpha_2
# 3                     True      LIG_AP2alpha_2
# 4                     True      LIG_AP2alpha_2
# ...                    ...                 ...
# 2380                 False  LIG_14-3-3_CanoR_1
# 2381                 False  LIG_14-3-3_CanoR_1
# 2382                 False  LIG_14-3-3_CanoR_1
# 2383                 False  LIG_14-3-3_CanoR_1
# 2384                 False  LIG_14-3-3_CanoR_1
#
# [2385 rows x 11 columns]

# %%
elms_df.groupby('verified interaction')['ELM_motif_class'].value_counts().unstack()
# Out:
# ELM_motif_class       DOC_WW_Pin1_4  LIG_14-3-3_CanoR_1  LIG_AP2alpha_2  \
# verified interaction
# False                           347                 347             349
# True                             82                  55              50
#
# ELM_motif_class       LIG_EH_1  LIG_SH2_GRB2like  LIG_SH3_CIN85_PxpxPR_1
# verified interaction
# False                      340               346                     350
# True                        56                30                      33

# %% [markdown]
# ---

# %% [markdown]
# # manually curated verified interactions

# %% [markdown]
# ## ENAH with [FL]PPPP regex

# %%
from orthodb_tools.orthogroup_processing import uniprotid_search

# %% [markdown]
# Get the regex matches for the verified binders first

# %% [markdown]
# import the annotated binders

# %%
df
# Out:
#          Organism Primary_Acc  \
# 0    Homo sapiens      P78314
# 1    Homo sapiens      P78314
# 2    Homo sapiens      Q9P0K1
# 3    Homo sapiens      P54253
# 4    Mus musculus      Q61337
# ..            ...         ...
# 397  Homo sapiens         NaN
# 398  Homo sapiens         NaN
# 399  Homo sapiens         NaN
# 400  Homo sapiens         NaN
# 401  Homo sapiens         NaN
#
#                                            Accessions   UniprotID  \
# 0    P78314 A6NNC2 B2R5R6 D3DVR0 O00500 O15373 P78315      P78314
# 1    P78314 A6NNC2 B2R5R6 D3DVR0 O00500 O15373 P78315      P78314
# 2           Q9P0K1 O75075 O75076 Q9P0K2 Q9UIA1 Q9UKK2      Q9P0K1
# 3                         P54253 Q17S02 Q9UJG2 Q9Y4J1      P54253
# 4                                              Q61337      Q61337
# ..                                                ...         ...
# 397                                               NaN  A0A384NPH9
# 398                                               NaN      Q9BWT1
# 399                                               NaN      A0PJX4
# 400                                               NaN      B3KUE8
# 401                                               NaN      O60331
#
#                                                  regex  motif_match  \
# 0    R[^DE]{0,2}[^DEPG]([ST])(([FWYLMV].)|([^PRIKGN...       RAHSFT
# 1    R[^DE]{0,2}[^DEPG]([ST])(([FWYLMV].)|([^PRIKGN...        RMSDP
# 2    R[^DE]{0,2}[^DEPG]([ST])(([FWYLMV].)|([^PRIKGN...       RSNSWQ
# 3    R[^DE]{0,2}[^DEPG]([ST])(([FWYLMV].)|([^PRIKGN...        RWSAP
# 4    R[^DE]{0,2}[^DEPG]([ST])(([FWYLMV].)|([^PRIKGN...       RHSSYP
# ..                                                 ...          ...
# 397  R[^DE]{0,2}[^DEPG]([ST])(([FWYLMV].)|([^PRIKGN...   RKSSSSRTPL
# 398  R[^DE]{0,2}[^DEPG]([ST])(([FWYLMV].)|([^PRIKGN...   RRSRSSVTLP
# 399  R[^DE]{0,2}[^DEPG]([ST])(([FWYLMV].)|([^PRIKGN...        RFSLR
# 400  R[^DE]{0,2}[^DEPG]([ST])(([FWYLMV].)|([^PRIKGN...  RATRSQQHTPV
# 401  R[^DE]{0,2}[^DEPG]([ST])(([FWYLMV].)|([^PRIKGN...      RGARSYP
#
#              odb_id  odb_mot_st  odb_mot_end  verified interaction  \
# 0     9606_0:00126f         278          283                  True
# 1     9606_0:00126f         332          336                  True
# 2     9606_0:001dbe         859          864                  True
# 3     9606_0:001b8c         772          776                  True
# 4    10090_0:0052d5         108          113                  True
# ..              ...         ...          ...                   ...
# 397   9606_0:000abb         504          513                 False
# 398   9606_0:000b49         305          314                 False
# 399   9606_0:001415         134          138                 False
# 400   9606_0:003ba5         843          853                 False
# 401   9606_0:0045b2         491          497                 False
#
#         ELM_motif_class
# 0    LIG_14-3-3_CanoR_1
# 1    LIG_14-3-3_CanoR_1
# 2    LIG_14-3-3_CanoR_1
# 3    LIG_14-3-3_CanoR_1
# 4    LIG_14-3-3_CanoR_1
# ..                  ...
# 397  LIG_14-3-3_CanoR_1
# 398  LIG_14-3-3_CanoR_1
# 399  LIG_14-3-3_CanoR_1
# 400  LIG_14-3-3_CanoR_1
# 401  LIG_14-3-3_CanoR_1
#
# [402 rows x 11 columns]

# %%
enah_table = "../../../../data/manually_curated_interactions/ena_vasp_benchmark.xlsx"
df = pd.read_excel(enah_table)
df['Uniprot ID'] = df['Uniprot ID'].str.strip()
verif_ids = df['Uniprot ID'].unique()
verif_id_dict = df[['Uniprot ID', 'name']].drop_duplicates().set_index('Uniprot ID').to_dict()['name']
assert set(verif_ids) == set(list(verif_id_dict.keys()))

# %%
REGEX = '[FL]PPPP'
CLASS_NAME = 'enah_LPPPP_FPPPP'

# %%
import orthodb_tools.env_variables.env_variables as env
ORTHODB_DATABASE = env.orthoDBDatabase()

# %%
def uni2odb_ids(uniprot_ids):
    odb2uni = {}
    for i in uniprot_ids:
        try:
            odb_id = uniprotid_search.uniprotid_2_odb_gene_id(i)
            # uni2odb[i] = odb_id
            odb2uni[odb_id] = i
        except ValueError as e:
            print(e)
            print(f"COULD NOT FIND: {i}, {ligands[i]}")
            continue
    return odb2uni


def get_verif_table_custom(
    uniprot_ids: list,
    regex: str,
    idr_map: dict|None,
    seq_organism: str = "Homo sapiens",
):
    odb2uni = uni2odb_ids(uniprot_ids)
    seq_list = [ORTHODB_DATABASE.data_all_seqrecords_dict[i] for i in odb2uni.keys()]
    df_verified = regex_search(regex, seq_list, idr_map=idr_map)
    df_verified["UniprotID"] = df_verified["odb_id"].map(odb2uni)
    df_verified["verified interaction"] = True
    df_verified["Organism"] = seq_organism
    return df_verified

# %%
df_verified = get_verif_table_custom(
    verif_ids,
    regex=REGEX,
    idr_map=idr_map,
    seq_organism="Homo sapiens"
)
# Out:
# Q8WX93 not found in gene key table, searching in xref table
# Q70E73 not found in gene key table, searching in xref table
# Q9Y6N7 not found in gene key table, searching in xref table
# Q8TF72 not found in gene key table, searching in xref table
# P18206 not found in gene key table, searching in xref table

# %%
df_verified['name'] = df_verified['UniprotID'].map(verif_id_dict)
df_verified
# Out:
#            odb_id  odb_mot_st  odb_mot_end motif_match     regex UniprotID  \
# 0   9606_0:00294e         127          131       LPPPP  [FL]PPPP    Q7Z5R6
# 1   9606_0:00294e         140          144       LPPPP  [FL]PPPP    Q7Z5R6
# 2   9606_0:00294e         515          519       LPPPP  [FL]PPPP    Q7Z5R6
# 3   9606_0:00294e         553          557       LPPPP  [FL]PPPP    Q7Z5R6
# 4   9606_0:00294e         567          571       LPPPP  [FL]PPPP    Q7Z5R6
# 5   9606_0:00294e         597          601       LPPPP  [FL]PPPP    Q7Z5R6
# 6   9606_0:003dae         276          280       LPPPP  [FL]PPPP    Q9P2A4
# 7   9606_0:003dae         289          293       LPPPP  [FL]PPPP    Q9P2A4
# 8   9606_0:0027f1        3253         3257       FPPPP  [FL]PPPP    Q12955
# 9   9606_0:00122c        4307         4311       LPPPP  [FL]PPPP    Q14517
# 10  9606_0:00122c        4434         4438       FPPPP  [FL]PPPP    Q14517
# 11  9606_0:000661         103          107       LPPPP  [FL]PPPP    Q8WUP2
# 12  9606_0:000661         165          169       LPPPP  [FL]PPPP    Q8WUP2
# 13  9606_0:0015fb         401          405       LPPPP  [FL]PPPP    O15117
# 14  9606_0:0015fb         625          629       FPPPP  [FL]PPPP    O15117
# 15  9606_0:000d90          67           71       LPPPP  [FL]PPPP    Q93052
# 16  9606_0:000d90          87           91       FPPPP  [FL]PPPP    Q93052
# 17  9606_0:001b40         953          957       LPPPP  [FL]PPPP    Q5SYE7
# 18  9606_0:001b40         974          978       FPPPP  [FL]PPPP    Q5SYE7
# 19  9606_0:00141f         561          565       FPPPP  [FL]PPPP    Q8WX93
# 20  9606_0:00094d         829          833       LPPPP  [FL]PPPP    A6NGG8
# 21  9606_0:000b76         627          631       LPPPP  [FL]PPPP    Q70E73
# 22  9606_0:000b76         868          872       FPPPP  [FL]PPPP    Q70E73
# 23  9606_0:000b76         915          919       FPPPP  [FL]PPPP    Q70E73
# 24  9606_0:000b76         926          930       FPPPP  [FL]PPPP    Q70E73
# 25  9606_0:000b76        1072         1076       FPPPP  [FL]PPPP    Q70E73
# 26  9606_0:000b76        1201         1205       LPPPP  [FL]PPPP    Q70E73
# 27  9606_0:000e6f        1185         1189       LPPPP  [FL]PPPP    Q9Y6N7
# 28  9606_0:000e6f        1479         1483       LPPPP  [FL]PPPP    Q9Y6N7
# 29  9606_0:002a4b        1052         1056       FPPPP  [FL]PPPP    O15357
# 30  9606_0:0012c3        1525         1529       LPPPP  [FL]PPPP    Q8TF72
# 31  9606_0:0012c3        1545         1549       FPPPP  [FL]PPPP    Q8TF72
# 32  9606_0:002935         841          845       FPPPP  [FL]PPPP    P18206
# 33  9606_0:000f47          23           27       LPPPP  [FL]PPPP    Q702N8
# 34  9606_0:001d2c          72           76       LPPPP  [FL]PPPP    Q15942
# 35  9606_0:001d2c          92           96       FPPPP  [FL]PPPP    Q15942
#
#     verified interaction      Organism         name
# 0                   True  Homo sapiens  AB1IP_HUMAN
# 1                   True  Homo sapiens  AB1IP_HUMAN
# 2                   True  Homo sapiens  AB1IP_HUMAN
# 3                   True  Homo sapiens  AB1IP_HUMAN
# 4                   True  Homo sapiens  AB1IP_HUMAN
# 5                   True  Homo sapiens  AB1IP_HUMAN
# 6                   True  Homo sapiens   ABI3_HUMAN
# 7                   True  Homo sapiens   ABI3_HUMAN
# 8                   True  Homo sapiens   ANK3_HUMAN
# 9                   True  Homo sapiens   FAT1_HUMAN
# 10                  True  Homo sapiens   FAT1_HUMAN
# 11                  True  Homo sapiens  FBLI1_HUMAN
# 12                  True  Homo sapiens  FBLI1_HUMAN
# 13                  True  Homo sapiens   FYB1_HUMAN
# 14                  True  Homo sapiens   FYB1_HUMAN
# 15                  True  Homo sapiens    LPP_HUMAN
# 16                  True  Homo sapiens    LPP_HUMAN
# 17                  True  Homo sapiens  NHSL1_HUMAN
# 18                  True  Homo sapiens  NHSL1_HUMAN
# 19                  True  Homo sapiens  PALLD_HUMAN
# 20                  True  Homo sapiens  PCARE_HUMAN
# 21                  True  Homo sapiens  RAPH1_HUMAN
# 22                  True  Homo sapiens  RAPH1_HUMAN
# 23                  True  Homo sapiens  RAPH1_HUMAN
# 24                  True  Homo sapiens  RAPH1_HUMAN
# 25                  True  Homo sapiens  RAPH1_HUMAN
# 26                  True  Homo sapiens  RAPH1_HUMAN
# 27                  True  Homo sapiens  ROBO1_HUMAN
# 28                  True  Homo sapiens  ROBO1_HUMAN
# 29                  True  Homo sapiens  SHIP2_HUMAN
# 30                  True  Homo sapiens  SHRM3_HUMAN
# 31                  True  Homo sapiens  SHRM3_HUMAN
# 32                  True  Homo sapiens   VINC_HUMAN
# 33                  True  Homo sapiens  XIRP1_HUMAN
# 34                  True  Homo sapiens    ZYX_HUMAN
# 35                  True  Homo sapiens    ZYX_HUMAN

# %%
elm_instances_df = pd.read_csv(ELM_INSTANCES_FILE)
df_bg = get_bg_seqs(BG_SEQ_FASTA_FILE, regex=REGEX, instance_df=elm_instances_df, idr_map=idr_map, bg_organism=BG_ORGANISM)
df_bg = df_bg.sample(350, random_state=42)
dfm = merge_verified_and_fp_motifs(df_verified, df_bg, cluster_dict=BG_CLUSTER_DICT)
dfm['ELM_motif_class'] = CLASS_NAME
# Out:
# added cluster members
# added cluster members
# added cluster members
# added cluster members
# added cluster members
# added cluster members
# added cluster members
# added cluster members
# added cluster members
# added cluster members
# added cluster members
# added cluster members
# added cluster members
# added cluster members
# added cluster members
# added cluster members
# added cluster members

# %%
print(len(dfm))
print(len(elms_df))
# Out:
# 364
# 2385

# %%
benchmark_df = pd.concat([elms_df, dfm]).reset_index(drop=True)

# %% [markdown]
# ## TRAF6

# %%
traf_table = "../../../../data/manually_curated_interactions/traf6_table.csv"
df = pd.read_csv(traf_table)
df['Uniprot ID'] = df['Uniprot ID'].str.strip()
df = df.rename(columns = {'Uniprot ID':'UniprotID','SLiM sequence':'motif_match'})

# %% [markdown]
# You could make the regex more specific to reduce the number of false positives<br>
# It might actually be better to use the information we know about unfavorable residues to make the false positives more likely to be real false positives. That said it's probably safer for now to just use the same regex for both TPs and FPs.
# - normal regex: `...P.E..[FYWHDE]`
# - numbering: `(-3)(-2)(-1)(0)(+1)(+2)(+3)(+4)(+5)`
# - Removing unfavorable residues from the regex:
#   - proline at any position between (+1) and (+5)
#     - it binds as a beta sheet
#   - a positively charged residue (RK) at positions (+3), (+4), or (+5)

# %%
# REGEX='...P[^P]E[^PRK][^PRK][FYWDE]'
REGEX='...P.E..[FYWDE]'
CLASS_NAME='TRAF6'

# %%
def odb_id_2_species_name(odb_gene_id: str):
    spec_id=sql_queries.odb_gene_id_2_species_id(odb_gene_id)
    return ORTHODB_DATABASE.data_species_dict[spec_id]


def get_verif_table_custom2(
    uniprot_ids: list,
    regex: str,
):
    odb2uni = uni2odb_ids(uniprot_ids)
    seq_list = [ORTHODB_DATABASE.data_all_seqrecords_dict[i] for i in odb2uni.keys()]
    df_verified = regex_search(regex, seq_list, idr_map=None)
    df_verified["UniprotID"] = df_verified["odb_id"].map(odb2uni)
    df_verified["verified interaction"] = True
    df_verified["Organism"] = df_verified["odb_id"].apply(odb_id_2_species_name)
    return df_verified

# %%
df_verified = get_verif_table_custom2(
    list(df['UniprotID'].unique()),
    regex=REGEX,
)
# Out:
# P25942 not found in gene key table, searching in xref table
# P51617 not found in gene key table, searching in xref table

# %%
df
# Out:
#                       Name UniprotID motif_match      OrthoDB id  \
# 0                     CD40    P25942   KQEPQEINF   9606_0:004882
# 1                     TIFA    Q96CG3   SSSPTEMDE   9606_0:001440
# 2                     MAVS    Q7Z434   CHGPEENEY   9606_0:00486f
# 3                   TICAM1    Q8IUC6   CQEPEEMSW   9606_0:004368
# 4                    IRAK2    O43187   SNTPEETDD   9606_0:000e31
# 5                    IRAK1    P51617   PPSPQENSY   9606_0:004fa3
# 6                    IRAK1    P51617   PNQPVESDE   9606_0:004fa3
# 7                    IRAK1    P51617   RQGPEESDE   9606_0:004fa3
# 8           IRAK3 (IRAK-M)    Q9Y616   PSIPVEDDE   9606_0:0031e9
# 9   mouse TNFRSF11A (RANK)    O35305   RKIPTEDEY  10090_0:000361
# 10  mouse TNFRSF11A (RANK)    O35305   FQEPLEVGE  10090_0:000361
# 11  mouse TNFRSF11A (RANK)    O35305   GNTPGEDHE  10090_0:000361
#
#                                         reference DOI
# 0    10.1073/pnas.96.4.1234, 10.1074/jbc.274.20.14246
# 1                              10.1002/cbic.201800436
# 2                             10.1074/jbc.M115.666578
# 3   10.1073/pnas.0308496101, 10.4049/jimmunol.171....
# 4                                 10.1038/nature00888
# 5                                 10.1038/nature00888
# 6                                 10.1038/nature00888
# 7                                 10.1038/nature00888
# 8                                 10.1038/nature00888
# 9                                 10.1038/nature00888
# 10                                10.1038/nature00888
# 11                                10.1038/nature00888

# %%
df_verified
# Out:
#             odb_id  odb_mot_st  odb_mot_end motif_match            regex  \
# 0    9606_0:004882         233          241   KQEPQEINF  ...P.E..[FYWDE]
# 1    9606_0:001440         172          180   SSSPTEMDE  ...P.E..[FYWDE]
# 2    9606_0:00486f         149          157   PESPGENSE  ...P.E..[FYWDE]
# 3    9606_0:00486f         451          459   CHGPEENEY  ...P.E..[FYWDE]
# 4    9606_0:004368          82           90   TEDPEEPPD  ...P.E..[FYWDE]
# 5    9606_0:004368         246          254   CQEPEEMSW  ...P.E..[FYWDE]
# 6    9606_0:004368         297          305   TNYPVECTE  ...P.E..[FYWDE]
# 7    9606_0:000e31         522          530   SNTPEETDD  ...P.E..[FYWDE]
# 8    9606_0:000e31         553          561   PLLPTENGE  ...P.E..[FYWDE]
# 9    9606_0:004fa3         538          546   PPSPQENSY  ...P.E..[FYWDE]
# 10   9606_0:004fa3         581          589   PNQPVESDE  ...P.E..[FYWDE]
# 11   9606_0:004fa3         700          708   RQGPEESDE  ...P.E..[FYWDE]
# 12   9606_0:0031e9         107          115   VLSPSEKSY  ...P.E..[FYWDE]
# 13   9606_0:0031e9         474          482   PSIPVEDDE  ...P.E..[FYWDE]
# 14  10090_0:000361          70           78   PCGPDEYLD  ...P.E..[FYWDE]
# 15  10090_0:000361         336          344   RKIPTEDEY  ...P.E..[FYWDE]
# 16  10090_0:000361         369          377   FQEPLEVGE  ...P.E..[FYWDE]
# 17  10090_0:000361         443          451   GNTPGEDHE  ...P.E..[FYWDE]
#
#    UniprotID  verified interaction      Organism
# 0     P25942                  True  Homo sapiens
# 1     Q96CG3                  True  Homo sapiens
# 2     Q7Z434                  True  Homo sapiens
# 3     Q7Z434                  True  Homo sapiens
# 4     Q8IUC6                  True  Homo sapiens
# 5     Q8IUC6                  True  Homo sapiens
# 6     Q8IUC6                  True  Homo sapiens
# 7     O43187                  True  Homo sapiens
# 8     O43187                  True  Homo sapiens
# 9     P51617                  True  Homo sapiens
# 10    P51617                  True  Homo sapiens
# 11    P51617                  True  Homo sapiens
# 12    Q9Y616                  True  Homo sapiens
# 13    Q9Y616                  True  Homo sapiens
# 14    O35305                  True  Mus musculus
# 15    O35305                  True  Mus musculus
# 16    O35305                  True  Mus musculus
# 17    O35305                  True  Mus musculus

# %% [markdown]
# merge the regex matches with the annotated binders to restrict the "verified" interactions to only those specific sequences in the original excel file. For this protein, I don't just want to take the regex matches from proteins that are known to bind, I want the specific sequences that are known to bind.<br>
#
# You could say that I should have done the same thing for enah, but I think the fact that I used the [LF]PPPP regex will make the matches very very likely to be real.

# %%
df_verified=pd.merge(left=df, right=df_verified, how='left', on=['UniprotID', 'motif_match'])

# %%
df_verified
# Out:
#                       Name UniprotID motif_match      OrthoDB id  \
# 0                     CD40    P25942   KQEPQEINF   9606_0:004882
# 1                     TIFA    Q96CG3   SSSPTEMDE   9606_0:001440
# 2                     MAVS    Q7Z434   CHGPEENEY   9606_0:00486f
# 3                   TICAM1    Q8IUC6   CQEPEEMSW   9606_0:004368
# 4                    IRAK2    O43187   SNTPEETDD   9606_0:000e31
# 5                    IRAK1    P51617   PPSPQENSY   9606_0:004fa3
# 6                    IRAK1    P51617   PNQPVESDE   9606_0:004fa3
# 7                    IRAK1    P51617   RQGPEESDE   9606_0:004fa3
# 8           IRAK3 (IRAK-M)    Q9Y616   PSIPVEDDE   9606_0:0031e9
# 9   mouse TNFRSF11A (RANK)    O35305   RKIPTEDEY  10090_0:000361
# 10  mouse TNFRSF11A (RANK)    O35305   FQEPLEVGE  10090_0:000361
# 11  mouse TNFRSF11A (RANK)    O35305   GNTPGEDHE  10090_0:000361
#
#                                         reference DOI          odb_id  \
# 0    10.1073/pnas.96.4.1234, 10.1074/jbc.274.20.14246   9606_0:004882
# 1                              10.1002/cbic.201800436   9606_0:001440
# 2                             10.1074/jbc.M115.666578   9606_0:00486f
# 3   10.1073/pnas.0308496101, 10.4049/jimmunol.171....   9606_0:004368
# 4                                 10.1038/nature00888   9606_0:000e31
# 5                                 10.1038/nature00888   9606_0:004fa3
# 6                                 10.1038/nature00888   9606_0:004fa3
# 7                                 10.1038/nature00888   9606_0:004fa3
# 8                                 10.1038/nature00888   9606_0:0031e9
# 9                                 10.1038/nature00888  10090_0:000361
# 10                                10.1038/nature00888  10090_0:000361
# 11                                10.1038/nature00888  10090_0:000361
#
#     odb_mot_st  odb_mot_end            regex  verified interaction  \
# 0          233          241  ...P.E..[FYWDE]                  True
# 1          172          180  ...P.E..[FYWDE]                  True
# 2          451          459  ...P.E..[FYWDE]                  True
# 3          246          254  ...P.E..[FYWDE]                  True
# 4          522          530  ...P.E..[FYWDE]                  True
# 5          538          546  ...P.E..[FYWDE]                  True
# 6          581          589  ...P.E..[FYWDE]                  True
# 7          700          708  ...P.E..[FYWDE]                  True
# 8          474          482  ...P.E..[FYWDE]                  True
# 9          336          344  ...P.E..[FYWDE]                  True
# 10         369          377  ...P.E..[FYWDE]                  True
# 11         443          451  ...P.E..[FYWDE]                  True
#
#         Organism
# 0   Homo sapiens
# 1   Homo sapiens
# 2   Homo sapiens
# 3   Homo sapiens
# 4   Homo sapiens
# 5   Homo sapiens
# 6   Homo sapiens
# 7   Homo sapiens
# 8   Homo sapiens
# 9   Mus musculus
# 10  Mus musculus
# 11  Mus musculus

# %%
df_verified = df_verified.drop(columns=['OrthoDB id'])
df_verified = df_verified.rename(columns={'Name':'name'})

# %%
df_verified
# Out:
#                       name UniprotID motif_match  \
# 0                     CD40    P25942   KQEPQEINF
# 1                     TIFA    Q96CG3   SSSPTEMDE
# 2                     MAVS    Q7Z434   CHGPEENEY
# 3                   TICAM1    Q8IUC6   CQEPEEMSW
# 4                    IRAK2    O43187   SNTPEETDD
# 5                    IRAK1    P51617   PPSPQENSY
# 6                    IRAK1    P51617   PNQPVESDE
# 7                    IRAK1    P51617   RQGPEESDE
# 8           IRAK3 (IRAK-M)    Q9Y616   PSIPVEDDE
# 9   mouse TNFRSF11A (RANK)    O35305   RKIPTEDEY
# 10  mouse TNFRSF11A (RANK)    O35305   FQEPLEVGE
# 11  mouse TNFRSF11A (RANK)    O35305   GNTPGEDHE
#
#                                         reference DOI          odb_id  \
# 0    10.1073/pnas.96.4.1234, 10.1074/jbc.274.20.14246   9606_0:004882
# 1                              10.1002/cbic.201800436   9606_0:001440
# 2                             10.1074/jbc.M115.666578   9606_0:00486f
# 3   10.1073/pnas.0308496101, 10.4049/jimmunol.171....   9606_0:004368
# 4                                 10.1038/nature00888   9606_0:000e31
# 5                                 10.1038/nature00888   9606_0:004fa3
# 6                                 10.1038/nature00888   9606_0:004fa3
# 7                                 10.1038/nature00888   9606_0:004fa3
# 8                                 10.1038/nature00888   9606_0:0031e9
# 9                                 10.1038/nature00888  10090_0:000361
# 10                                10.1038/nature00888  10090_0:000361
# 11                                10.1038/nature00888  10090_0:000361
#
#     odb_mot_st  odb_mot_end            regex  verified interaction  \
# 0          233          241  ...P.E..[FYWDE]                  True
# 1          172          180  ...P.E..[FYWDE]                  True
# 2          451          459  ...P.E..[FYWDE]                  True
# 3          246          254  ...P.E..[FYWDE]                  True
# 4          522          530  ...P.E..[FYWDE]                  True
# 5          538          546  ...P.E..[FYWDE]                  True
# 6          581          589  ...P.E..[FYWDE]                  True
# 7          700          708  ...P.E..[FYWDE]                  True
# 8          474          482  ...P.E..[FYWDE]                  True
# 9          336          344  ...P.E..[FYWDE]                  True
# 10         369          377  ...P.E..[FYWDE]                  True
# 11         443          451  ...P.E..[FYWDE]                  True
#
#         Organism
# 0   Homo sapiens
# 1   Homo sapiens
# 2   Homo sapiens
# 3   Homo sapiens
# 4   Homo sapiens
# 5   Homo sapiens
# 6   Homo sapiens
# 7   Homo sapiens
# 8   Homo sapiens
# 9   Mus musculus
# 10  Mus musculus
# 11  Mus musculus

# %%
elm_instances_df = pd.read_csv(ELM_INSTANCES_FILE)
df_bg = get_bg_seqs(
    BG_SEQ_FASTA_FILE,
    regex=REGEX,
    instance_df=elm_instances_df,
    idr_map=idr_map,
    bg_organism=BG_ORGANISM,
)
df_bg = df_bg.sample(300, random_state=42)
dfm = merge_verified_and_fp_motifs(df_verified, df_bg, cluster_dict=BG_CLUSTER_DICT)
dfm["ELM_motif_class"] = CLASS_NAME
# Out:
# added cluster members
# added cluster members
# added cluster members
# added cluster members
# added cluster members
# added cluster members
# added cluster members

# %%
print(len(dfm))
# Out:
# 312

# %%
dfm
# Out:
#        name   UniprotID motif_match  \
# 0      CD40      P25942   KQEPQEINF
# 1      TIFA      Q96CG3   SSSPTEMDE
# 2      MAVS      Q7Z434   CHGPEENEY
# 3    TICAM1      Q8IUC6   CQEPEEMSW
# 4     IRAK2      O43187   SNTPEETDD
# ..      ...         ...         ...
# 307     NaN  A0A1B0GUS7   ACEPKEMKE
# 308     NaN      O00592   DQGPPEEAE
# 309     NaN      B2RAH2   VADPYEEAW
# 310     NaN      Q96QZ7   GNEPGEPIY
# 311     NaN      O95786   SCPPSEVSD
#
#                                          reference DOI         odb_id  \
# 0     10.1073/pnas.96.4.1234, 10.1074/jbc.274.20.14246  9606_0:004882
# 1                               10.1002/cbic.201800436  9606_0:001440
# 2                              10.1074/jbc.M115.666578  9606_0:00486f
# 3    10.1073/pnas.0308496101, 10.4049/jimmunol.171....  9606_0:004368
# 4                                  10.1038/nature00888  9606_0:000e31
# ..                                                 ...            ...
# 307                                                NaN  9606_0:002617
# 308                                                NaN  9606_0:001d9e
# 309                                                NaN  9606_0:00030a
# 310                                                NaN  9606_0:000f0e
# 311                                                NaN  9606_0:00269f
#
#      odb_mot_st  odb_mot_end            regex  verified interaction  \
# 0           233          241  ...P.E..[FYWDE]                  True
# 1           172          180  ...P.E..[FYWDE]                  True
# 2           451          459  ...P.E..[FYWDE]                  True
# 3           246          254  ...P.E..[FYWDE]                  True
# 4           522          530  ...P.E..[FYWDE]                  True
# ..          ...          ...              ...                   ...
# 307        3076         3084  ...P.E..[FYWDE]                 False
# 308         446          454  ...P.E..[FYWDE]                 False
# 309         654          662  ...P.E..[FYWDE]                 False
# 310         829          837  ...P.E..[FYWDE]                 False
# 311         225          233  ...P.E..[FYWDE]                 False
#
#          Organism ELM_motif_class
# 0    Homo sapiens           TRAF6
# 1    Homo sapiens           TRAF6
# 2    Homo sapiens           TRAF6
# 3    Homo sapiens           TRAF6
# 4    Homo sapiens           TRAF6
# ..            ...             ...
# 307  Homo sapiens           TRAF6
# 308  Homo sapiens           TRAF6
# 309  Homo sapiens           TRAF6
# 310  Homo sapiens           TRAF6
# 311  Homo sapiens           TRAF6
#
# [312 rows x 11 columns]

# %%
benchmark_df = pd.concat([benchmark_df, dfm]).reset_index(drop=True)

# %%
benchmark_df
# Out:
#                Organism Primary_Acc                          Accessions  \
# 0     Rattus norvegicus      O08838                              O08838
# 1     Rattus norvegicus      Q05140                              Q05140
# 2     Rattus norvegicus      Q05140                              Q05140
# 3          Homo sapiens      P98082  P98082 A6NES5 Q13598 Q9BTY0 Q9UK04
# 4          Homo sapiens      P98082  P98082 A6NES5 Q13598 Q9BTY0 Q9UK04
# ...                 ...         ...                                 ...
# 3056       Homo sapiens         NaN                                 NaN
# 3057       Homo sapiens         NaN                                 NaN
# 3058       Homo sapiens         NaN                                 NaN
# 3059       Homo sapiens         NaN                                 NaN
# 3060       Homo sapiens         NaN                                 NaN
#
#        UniprotID            regex motif_match          odb_id  odb_mot_st  \
# 0         O08838           DP[FW]         DPF  10116_0:004cdf         356
# 1         Q05140           DP[FW]         DPF  10116_0:002e5e         399
# 2         Q05140           DP[FW]         DPF  10116_0:002e5e         473
# 3         P98082           DP[FW]         DPF   9606_0:0016b2         292
# 4         P98082           DP[FW]         DPF   9606_0:0016b2         297
# ...          ...              ...         ...             ...         ...
# 3056  A0A1B0GUS7  ...P.E..[FYWDE]   ACEPKEMKE   9606_0:002617        3076
# 3057      O00592  ...P.E..[FYWDE]   DQGPPEEAE   9606_0:001d9e         446
# 3058      B2RAH2  ...P.E..[FYWDE]   VADPYEEAW   9606_0:00030a         654
# 3059      Q96QZ7  ...P.E..[FYWDE]   GNEPGEPIY   9606_0:000f0e         829
# 3060      O95786  ...P.E..[FYWDE]   SCPPSEVSD   9606_0:00269f         225
#
#       odb_mot_end  verified interaction ELM_motif_class name reference DOI
# 0             358                  True  LIG_AP2alpha_2  NaN           NaN
# 1             401                  True  LIG_AP2alpha_2  NaN           NaN
# 2             475                  True  LIG_AP2alpha_2  NaN           NaN
# 3             294                  True  LIG_AP2alpha_2  NaN           NaN
# 4             299                  True  LIG_AP2alpha_2  NaN           NaN
# ...           ...                   ...             ...  ...           ...
# 3056         3084                 False           TRAF6  NaN           NaN
# 3057          454                 False           TRAF6  NaN           NaN
# 3058          662                 False           TRAF6  NaN           NaN
# 3059          837                 False           TRAF6  NaN           NaN
# 3060          233                 False           TRAF6  NaN           NaN
#
# [3061 rows x 13 columns]

# %% [markdown]
# # filter out really long sequences

# %%
MAX_SEQ_LENGTH = 5000
# change to 4000 in the next iteration
# MAX_SEQ_LENGTH = 4000

# %%
def get_seq_length(odb_gene_id: str) -> int:
    return len(ORTHODB_DATABASE.data_all_seqrecords_dict[odb_gene_id].seq)

# %%
benchmark_df['seq_length'] = benchmark_df['odb_id'].apply(get_seq_length)
benchmark_df = benchmark_df[benchmark_df['seq_length'] < MAX_SEQ_LENGTH]

# %%
def map_fl_odb_seq(df_in: pd.DataFrame, odb_id_colname: str = "gene_id"):
    """
    adds column "odb_seq" to df_in
    """
    data_all_seqrecords_dict = env.load_data_all_odb_seqs()
    df = df_in.copy()
    df["odb_seq"] = df[odb_id_colname].apply(
        lambda x: (
            str(data_all_seqrecords_dict[x].seq)
            if x in data_all_seqrecords_dict.keys()
            else np.nan
        )
    )
    print(
        f"{df['odb_seq'].isna().sum()} rows where odb id could not be mapped to sequence"
    )
    return df

# %%
benchmark_df
# Out:
#                Organism Primary_Acc                          Accessions  \
# 0     Rattus norvegicus      O08838                              O08838
# 1     Rattus norvegicus      Q05140                              Q05140
# 2     Rattus norvegicus      Q05140                              Q05140
# 3          Homo sapiens      P98082  P98082 A6NES5 Q13598 Q9BTY0 Q9UK04
# 4          Homo sapiens      P98082  P98082 A6NES5 Q13598 Q9BTY0 Q9UK04
# ...                 ...         ...                                 ...
# 3056       Homo sapiens         NaN                                 NaN
# 3057       Homo sapiens         NaN                                 NaN
# 3058       Homo sapiens         NaN                                 NaN
# 3059       Homo sapiens         NaN                                 NaN
# 3060       Homo sapiens         NaN                                 NaN
#
#        UniprotID            regex motif_match          odb_id  odb_mot_st  \
# 0         O08838           DP[FW]         DPF  10116_0:004cdf         356
# 1         Q05140           DP[FW]         DPF  10116_0:002e5e         399
# 2         Q05140           DP[FW]         DPF  10116_0:002e5e         473
# 3         P98082           DP[FW]         DPF   9606_0:0016b2         292
# 4         P98082           DP[FW]         DPF   9606_0:0016b2         297
# ...          ...              ...         ...             ...         ...
# 3056  A0A1B0GUS7  ...P.E..[FYWDE]   ACEPKEMKE   9606_0:002617        3076
# 3057      O00592  ...P.E..[FYWDE]   DQGPPEEAE   9606_0:001d9e         446
# 3058      B2RAH2  ...P.E..[FYWDE]   VADPYEEAW   9606_0:00030a         654
# 3059      Q96QZ7  ...P.E..[FYWDE]   GNEPGEPIY   9606_0:000f0e         829
# 3060      O95786  ...P.E..[FYWDE]   SCPPSEVSD   9606_0:00269f         225
#
#       odb_mot_end  verified interaction ELM_motif_class name reference DOI  \
# 0             358                  True  LIG_AP2alpha_2  NaN           NaN
# 1             401                  True  LIG_AP2alpha_2  NaN           NaN
# 2             475                  True  LIG_AP2alpha_2  NaN           NaN
# 3             294                  True  LIG_AP2alpha_2  NaN           NaN
# 4             299                  True  LIG_AP2alpha_2  NaN           NaN
# ...           ...                   ...             ...  ...           ...
# 3056         3084                 False           TRAF6  NaN           NaN
# 3057          454                 False           TRAF6  NaN           NaN
# 3058          662                 False           TRAF6  NaN           NaN
# 3059          837                 False           TRAF6  NaN           NaN
# 3060          233                 False           TRAF6  NaN           NaN
#
#       seq_length
# 0            683
# 1            918
# 2            918
# 3            770
# 4            770
# ...          ...
# 3056        4340
# 3057         558
# 3058         815
# 3059        1462
# 3060         925
#
# [3000 rows x 14 columns]

# %%
benchmark_df = map_fl_odb_seq(benchmark_df, odb_id_colname="odb_id")
# Out:
# 0 rows where odb id could not be mapped to sequence

# %%
prohibited_chars = r"[Xx\*JBZU]"
benchmark_df=benchmark_df[~benchmark_df["odb_seq"].str.contains(prohibited_chars, regex=True)]

# %%
benchmark_df=benchmark_df.drop(columns=['odb_seq', 'seq_length'])

# %%
print(len(benchmark_df))
# Out:
# 2999

# %%
benchmark_df.groupby('ELM_motif_class')['verified interaction'].value_counts().unstack().fillna(0)
# Out:
# verified interaction    False  True
# ELM_motif_class
# DOC_WW_Pin1_4             328     82
# LIG_14-3-3_CanoR_1        334     55
# LIG_AP2alpha_2            341     50
# LIG_EH_1                  335     56
# LIG_SH2_GRB2like          341     30
# LIG_SH3_CIN85_PxpxPR_1    345     33
# TRAF6                     294     12
# enah_LPPPP_FPPPP          327     36

# %%
len(benchmark_df['odb_id'].unique())
# Out:
# 2218

# %%
rn_dict = {
    'motif_match': 'hit_sequence',
    'odb_id': 'gene_id',
    'odb_mot_st': 'hit start position',
    'odb_mot_end': 'hit end position',
}

benchmark_df = benchmark_df.rename(columns=rn_dict)

# %%
BENCHMARK_DIR / "benchmark_table.csv"
# Out:
# PosixPath('/home/jch/Documents/08-benchmark/benchmark/benchmark_v4/p1_table/benchmark_table.csv')

# %%
benchmark_df.to_csv(BENCHMARK_DIR / "benchmark_table.csv", index=False)
